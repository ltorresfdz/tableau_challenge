# %% [markdown]
# # IMPORTING DATA FROM CITIBAKE WEB PAG
#
# I used the coding shared on this article:
#
# https://medium.com/@dvillaveces/analyzing-citi-bike-data-2202f9da97d7

# %%
import requests
from bs4 import BeautifulSoup
import os
import zipfile
import numpy as np
import pandas as pd

# %%
url = 'https://s3.amazonaws.com/tripdata/'

# %%
# load url content into soup
r = requests.get(url)
soup = BeautifulSoup(r.text, 'xml')

# %%
# extract file names from soup
files = soup.find_all('Key')
clean_files = []
for i in range(len(files)-1):
    clean_files.append(files[i].get_text())

# %%
clean_files
# Out:
# ['201306-citibike-tripdata.zip',
#  '201307-201402-citibike-tripdata.zip',
#  '201307-citibike-tripdata.zip',
#  '201308-citibike-tripdata.zip',
#  '201309-citibike-tripdata.zip',
#  '201310-citibike-tripdata.zip',
#  '201311-citibike-tripdata.zip',
#  '201312-citibike-tripdata.zip',
#  '201401-citibike-tripdata.zip',
#  '201402-citibike-tripdata.zip',
#  '201403-citibike-tripdata.zip',
#  '201404-citibike-tripdata.zip',
#  '201405-citibike-tripdata.zip',
#  '201406-citibike-tripdata.zip',
#  '201407-citibike-tripdata.zip',
#  '201408-citibike-tripdata.zip',
#  '201409-citibike-tripdata.zip',
#  '201410-citibike-tripdata.zip',
#  '201411-citibike-tripdata.zip',
#  '201412-citibike-tripdata.zip',
#  '201501-citibike-tripdata.zip',
#  '201502-citibike-tripdata.zip',
#  '201503-citibike-tripdata.zip',
#  '201504-citibike-tripdata.zip',
#  '201505-citibike-tripdata.zip',
#  '201506-citibike-tripdata.zip',
#  '201507-citibike-tripdata.zip',
#  '201508-citibike-tripdata.zip',
# ...

# %%
# download & unzip data files
for file in clean_files:
    file_url = url + file
    #download files
    with open(file, "wb") as f:
            response = requests.get(file_url)
            f.write(response.content)
    # unzip data files
    with zipfile.ZipFile(file, "r") as zip_ref:
        zip_ref.extractall("tripdata")        
    # remove zipped file after unziping
    os.remove(file)

# %%
# rename files 
directory = 'tripdata/'
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith('.csv'):
        new_filename = filename.replace(' ','').lower().split('ci', 1)[0].strip('-').replace('-','_')
        os.rename(os.path.join(directory, filename), os.path.join(directory, new_filename + '.csv'))

# %%
#load into DataFrames into dfs dictionary
directory = 'tripdata/'
dfs = {}

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith('.csv'):
        dfs[filename.split('.')[0]] = pd.read_csv(os.path.join(directory, filename)) 
        
#takes about 5 min to run

# %%
#Review info and headers for some years
dfs['201601'].head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           923  1/1/2016 00:00:41  1/1/2016 00:16:04               268
# 1           379  1/1/2016 00:00:45  1/1/2016 00:07:04               476
# 2           589  1/1/2016 00:00:48  1/1/2016 00:10:37               489
# 3           889  1/1/2016 00:01:06  1/1/2016 00:15:56               268
# 4          1480  1/1/2016 00:01:12  1/1/2016 00:25:52              2006
#
#        start station name  start station latitude  start station longitude  \
# 0   Howard St & Centre St               40.719105               -73.999733
# 1         E 31 St & 3 Ave               40.743943               -73.979661
# 2        10 Ave & W 28 St               40.750664               -74.001768
# 3   Howard St & Centre St               40.719105               -73.999733
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
#    end station id            end station name  end station latitude  \
# ...

# %%
#Review info and headers for some years
dfs['201701'].head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
#Review info and headers for some years
dfs['201801'].head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
#Review info and headers for some years
dfs['201901'].head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1           316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2           591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3          2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4           303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
#
#    start station id           start station name  start station latitude  \
# 0            3160.0  Central Park West & W 76 St               40.778968
# 1             519.0        Pershing Square North               40.751873
# 2            3171.0      Amsterdam Ave & W 82 St               40.785247
# 3             504.0              1 Ave & E 16 St               40.732219
# 4             229.0               Great Jones St               40.727434
#
#    start station longitude  end station id        end station name  \
# ...

# %%
#Review info and headers for some years
dfs['202001'].head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# ...

# %%
#convert each dictionary to dataframe

df_2016_01 = pd.DataFrame.from_dict(dfs['201601'])
df_2016_02 = pd.DataFrame.from_dict(dfs['201602'])
df_2016_03 = pd.DataFrame.from_dict(dfs['201603'])
df_2016_04 = pd.DataFrame.from_dict(dfs['201604'])
df_2016_05 = pd.DataFrame.from_dict(dfs['201605'])
df_2016_06 = pd.DataFrame.from_dict(dfs['201606'])
df_2016_07 = pd.DataFrame.from_dict(dfs['201607'])
df_2016_08 = pd.DataFrame.from_dict(dfs['201608'])
df_2016_09 = pd.DataFrame.from_dict(dfs['201609'])
df_2016_10 = pd.DataFrame.from_dict(dfs['201610'])
df_2016_11 = pd.DataFrame.from_dict(dfs['201611'])
df_2016_12 = pd.DataFrame.from_dict(dfs['201612'])

df_2017_01 = pd.DataFrame.from_dict(dfs['201701'])
df_2017_02 = pd.DataFrame.from_dict(dfs['201702'])
df_2017_03 = pd.DataFrame.from_dict(dfs['201703'])
df_2017_04 = pd.DataFrame.from_dict(dfs['201704'])
df_2017_05 = pd.DataFrame.from_dict(dfs['201705'])
df_2017_06 = pd.DataFrame.from_dict(dfs['201706'])
df_2017_07 = pd.DataFrame.from_dict(dfs['201707'])
df_2017_08 = pd.DataFrame.from_dict(dfs['201708'])
df_2017_09 = pd.DataFrame.from_dict(dfs['201709'])
df_2017_10 = pd.DataFrame.from_dict(dfs['201710'])
df_2017_11 = pd.DataFrame.from_dict(dfs['201711'])
df_2017_12 = pd.DataFrame.from_dict(dfs['201712'])


df_2018_01 = pd.DataFrame.from_dict(dfs['201801'])
df_2018_02 = pd.DataFrame.from_dict(dfs['201802'])
df_2018_03 = pd.DataFrame.from_dict(dfs['201803'])
df_2018_04 = pd.DataFrame.from_dict(dfs['201804'])
df_2018_05 = pd.DataFrame.from_dict(dfs['201805'])
df_2018_06 = pd.DataFrame.from_dict(dfs['201806'])
df_2018_07 = pd.DataFrame.from_dict(dfs['201807'])
df_2018_08 = pd.DataFrame.from_dict(dfs['201808'])
df_2018_09 = pd.DataFrame.from_dict(dfs['201809'])
df_2018_10 = pd.DataFrame.from_dict(dfs['201810'])
df_2018_11 = pd.DataFrame.from_dict(dfs['201811'])
df_2018_12 = pd.DataFrame.from_dict(dfs['201812'])

df_2019_01 = pd.DataFrame.from_dict(dfs['201901'])
df_2019_02 = pd.DataFrame.from_dict(dfs['201902'])
df_2019_03 = pd.DataFrame.from_dict(dfs['201903'])
df_2019_04 = pd.DataFrame.from_dict(dfs['201904'])
df_2019_05 = pd.DataFrame.from_dict(dfs['201905'])
df_2019_06 = pd.DataFrame.from_dict(dfs['201906'])
df_2019_07 = pd.DataFrame.from_dict(dfs['201907'])
df_2019_08 = pd.DataFrame.from_dict(dfs['201908'])
df_2019_09 = pd.DataFrame.from_dict(dfs['201909'])
df_2019_10 = pd.DataFrame.from_dict(dfs['201910'])
df_2019_11 = pd.DataFrame.from_dict(dfs['201911'])
df_2019_12 = pd.DataFrame.from_dict(dfs['201912'])



df_2020_01 = pd.DataFrame.from_dict(dfs['202001'])
df_2020_02 = pd.DataFrame.from_dict(dfs['202002'])
df_2020_03 = pd.DataFrame.from_dict(dfs['202003'])
df_2020_04 = pd.DataFrame.from_dict(dfs['202004'])
df_2020_05 = pd.DataFrame.from_dict(dfs['202005'])
df_2020_06 = pd.DataFrame.from_dict(dfs['202006'])
df_2020_07 = pd.DataFrame.from_dict(dfs['202007'])
df_2020_08 = pd.DataFrame.from_dict(dfs['202008'])
df_2020_09 = pd.DataFrame.from_dict(dfs['202009'])
df_2020_10 = pd.DataFrame.from_dict(dfs['202010'])
df_2020_11 = pd.DataFrame.from_dict(dfs['202011'])

# %%
#review column titles
list(df_2016_01.columns)
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
#review column titles and select official column titles for all dataframes
column_titles = df_2016_12.columns
column_titles
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
#assign official column titles to all dataframes

df_2016_01.columns=column_titles
df_2016_02.columns=column_titles
df_2016_03.columns=column_titles 
df_2016_04.columns=column_titles 
df_2016_05.columns=column_titles 
df_2016_06.columns=column_titles 
df_2016_07.columns=column_titles 
df_2016_08.columns=column_titles 
df_2016_09.columns=column_titles 
df_2016_10.columns=column_titles 
df_2016_11.columns=column_titles 
df_2016_12.columns=column_titles 



df_2017_01.columns=column_titles
df_2017_02.columns=column_titles
df_2017_03.columns=column_titles 
df_2017_04.columns=column_titles 
df_2017_05.columns=column_titles 
df_2017_06.columns=column_titles 
df_2017_07.columns=column_titles 
df_2017_08.columns=column_titles 
df_2017_09.columns=column_titles 
df_2017_10.columns=column_titles 
df_2017_11.columns=column_titles 
df_2017_12.columns=column_titles 



df_2018_01.columns=column_titles
df_2018_02.columns=column_titles
df_2018_03.columns=column_titles 
df_2018_04.columns=column_titles 
df_2018_05.columns=column_titles 
df_2018_06.columns=column_titles 
df_2018_07.columns=column_titles 
df_2018_08.columns=column_titles 
df_2018_09.columns=column_titles 
df_2018_10.columns=column_titles 
df_2018_11.columns=column_titles 
df_2018_12.columns=column_titles 



df_2019_01.columns=column_titles
df_2019_02.columns=column_titles
df_2019_03.columns=column_titles 
df_2019_04.columns=column_titles 
df_2019_05.columns=column_titles 
df_2019_06.columns=column_titles 
df_2019_07.columns=column_titles 
df_2019_08.columns=column_titles 
df_2019_09.columns=column_titles 
df_2019_10.columns=column_titles 
df_2019_11.columns=column_titles 
df_2019_12.columns=column_titles 

df_2020_01.columns=column_titles
df_2020_02.columns=column_titles
df_2020_03.columns=column_titles 
df_2020_04.columns=column_titles 
df_2020_05.columns=column_titles 
df_2020_06.columns=column_titles 
df_2020_07.columns=column_titles 
df_2020_08.columns=column_titles 
df_2020_09.columns=column_titles 
df_2020_10.columns=column_titles 
df_2020_11.columns=column_titles

# %%
#create data frame by year

df_final_2016 = pd.concat([df_2016_01,df_2016_02,df_2016_03,df_2016_04,df_2016_05,df_2016_06,
                      df_2016_07, df_2016_08,df_2016_09,df_2016_10,df_2016_11,df_2016_12], ignore_index=True)

# %%
df_final_2016
# Out:
#           Trip Duration           Start Time            Stop Time  \
# 0                   923    1/1/2016 00:00:41    1/1/2016 00:16:04
# 1                   379    1/1/2016 00:00:45    1/1/2016 00:07:04
# 2                   589    1/1/2016 00:00:48    1/1/2016 00:10:37
# 3                   889    1/1/2016 00:01:06    1/1/2016 00:15:56
# 4                  1480    1/1/2016 00:01:12    1/1/2016 00:25:52
# ...                 ...                  ...                  ...
# 13845650            441  2016-12-31 23:56:15  2017-01-01 00:03:36
# 13845651           1026  2016-12-31 23:56:19  2017-01-01 00:13:26
# 13845652           1747  2016-12-31 23:56:35  2017-01-01 00:25:43
# 13845653            951  2016-12-31 23:59:31  2017-01-01 00:15:23
# 13845654           1322  2016-12-31 23:59:56  2017-01-01 00:21:58
#
#           Start Station ID                 Start Station Name  \
# 0                      268              Howard St & Centre St
# ...

# %%
df_final_2016.dtypes
# Out:
# Trip Duration                int64
# Start Time                  object
# Stop Time                   object
# Start Station ID             int64
# Start Station Name          object
# Start Station Latitude     float64
# Start Station Longitude    float64
# End Station ID               int64
# End Station Name            object
# End Station Latitude       float64
# End Station Longitude      float64
# Bike ID                      int64
# User Type                   object
# Birth Year                 float64
# Gender                       int64
# dtype: object

# %%
#review data on time column to verify if it is the same format.

df_final_2016['Start Time'].unique
# Out:
# <bound method Series.unique of 0             1/1/2016 00:00:41
# 1             1/1/2016 00:00:45
# 2             1/1/2016 00:00:48
# 3             1/1/2016 00:01:06
# 4             1/1/2016 00:01:12
#                    ...
# 13845650    2016-12-31 23:56:15
# 13845651    2016-12-31 23:56:19
# 13845652    2016-12-31 23:56:35
# 13845653    2016-12-31 23:59:31
# 13845654    2016-12-31 23:59:56
# Name: Start Time, Length: 13845655, dtype: object>

# %%
#create csv file for each year 

df_final_2016.to_csv('2016_data.csv')

# %%
df_final_2020 = pd.concat([df_2020_01,df_2020_02,df_2020_03,df_2020_04,df_2020_05,df_2020_06,
                      df_2020_07, df_2020_08,df_2020_09,df_2020_10,df_2020_11], ignore_index=True)

# %%
df_final_2020
# Out:
#           Trip Duration                Start Time                 Stop Time  \
# 0                   789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                  1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                  1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                   592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                   702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...                 ...                       ...                       ...
# 18417923            257  2020-11-30 23:58:44.6840  2020-12-01 00:03:01.9470
# 18417924            617  2020-11-30 23:58:45.6210  2020-12-01 00:09:02.8300
# 18417925            116  2020-11-30 23:58:45.7200  2020-12-01 00:00:41.9570
# 18417926            409  2020-11-30 23:59:20.1480  2020-12-01 00:06:09.7540
# 18417927            301  2020-11-30 23:59:47.9750  2020-12-01 00:04:49.2260
#
# ...

# %%
df_final_2020.to_csv('2020_data.csv')

# %%
df_final_2017 = pd.concat([df_2017_01,df_2017_02,df_2017_03,df_2017_04,df_2017_05,df_2017_06,
                           df_2017_07,df_2017_08,df_2017_09,df_2017_10,df_2017_11,df_2017_12], ignore_index=True)

# %%
df_final_2017.to_csv('2017_data.csv')

# %%
df_final_2018 = pd.concat([df_2018_01,df_2018_02,df_2018_03,df_2018_04,df_2018_05,df_2018_06,
                           df_2018_07,df_2018_08,df_2018_09,df_2018_10,df_2018_11,df_2018_12], ignore_index=True)

# %%
df_final_2018.to_csv('2018_data.csv')

# %%
df_final_2019 = pd.concat([df_2019_01,df_2019_02,df_2019_03,df_2019_04,df_2019_05,df_2019_06,
                           df_2019_07,df_2019_08,df_2019_09,df_2019_10,df_2019_11,df_2019_12], ignore_index=True)

# %%
df_final_2019.to_csv('2019_data.csv')
